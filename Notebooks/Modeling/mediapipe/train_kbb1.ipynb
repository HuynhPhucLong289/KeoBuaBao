# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
import pickle
# Out:
# WARNING:tensorflow:From e:\ML_project\venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_csv("E:\\ML_project\\toa_do_kbb.csv", header = None)         #Truy cập file 
df = df.dropna()                                                          #Loại bỏ giá trị thiếu

# %%
df.head()       #5 dòng đầu của file tạo độ
# Out:
#   0         1         2             3         4         5         6   \
# 0  k  0.375511  0.709129  6.290000e-07  0.439296  0.676939 -0.026391
# 1  k  0.375313  0.708683  6.300000e-07  0.438873  0.676522 -0.024865
# 2  k  0.375868  0.709061  6.410000e-07  0.439662  0.677594 -0.025331
# 3  k  0.379827  0.715435  6.500000e-07  0.443963  0.682880 -0.027255
# 4  k  0.377705  0.714899  6.430000e-07  0.442913  0.682189 -0.027841
#
#          7         8         9   ...        54        55        56        57  \
# 0  0.480929  0.609079 -0.036664  ... -0.037444  0.355986  0.508310 -0.075680
# 1  0.480665  0.608811 -0.034840  ... -0.038856  0.355501  0.509058 -0.076568
# 2  0.481834  0.609100 -0.035338  ... -0.039516  0.355037  0.510668 -0.078011
# 3  0.485071  0.611421 -0.037009  ... -0.035299  0.356802  0.512319 -0.075647
# 4  0.485150  0.611368 -0.037804  ... -0.034694  0.356760  0.511725 -0.074974
#
#          58        59        60        61        62        63
# 0  0.372472  0.560221 -0.076329  0.382586  0.603827 -0.065713
# 1  0.372494  0.560312 -0.077069  0.382653  0.604122 -0.066530
# 2  0.372602  0.562875 -0.078754  0.383301  0.606400 -0.068125
# 3  0.375290  0.566222 -0.077781  0.386658  0.610031 -0.067700
# 4  0.375762  0.565284 -0.077239  0.387870  0.608777 -0.067281
#
# [5 rows x 64 columns]

# %%
x_raw = df.iloc[:, 1:].values                                             #Lấy tất cả giá trị ở cột 1 tới cuối
y_raw = df.iloc[:, 0].values                                              #Lấy tất cả giá trị ở cột 0

# %%
n = np.unique(y_raw)                        #chuyen y_raw thanh numpy

# %%
chuyen_thanh_so = {}                        #chuyen thanh dict {a:1, b:0}
for i,lable in enumerate(n):
    chuyen_thanh_so[lable] = i

# %%
y_list = []                                 #Biến mảng ['a', 'a', 'b'] thành [0, 0, 1]
for key in y_raw:
    value = chuyen_thanh_so[key]
    y_list.append(value)
y_int = np.array(y_list)

# %%
cot = len(n)
onehot = np.zeros((len(y_int), cot))        #tao 1 mang toan 0 voi y_int hang va y_raw cot)
onehot[np.arange(len(y_int)), y_int] = 1    #gan gia tri o hang len(y_int) cot y_int thanh 1

# %%
x_train, x_test, y_train, y_test = train_test_split(x_raw, onehot, test_size=0.2, random_state=42) #chia file train, test

# %%
model = keras.Sequential([                      #tạo khung cho bộ não model
    layers.Input(shape = (63,)),                #tạo input
    layers.Dense(256, activation = 'relu'),     #tạo lớp dense lấy đặc điểm
    layers.Dropout(0.2),                        #tắt ngẫu nhiên 20% no ron ở lớp trên
    layers.Dense(128, activation = 'relu'),
    layers.BatchNormalization(),                #
    layers.Dense(64, activation = 'relu'),      #tổng các các đặc điểm từ lớp dense ở trên
    layers.Dense(len(n), activation = 'softmax')     #tong hop cac lop o tren roi chuyen ket qua ve dang%
])
# Out:
# WARNING:tensorflow:From e:\ML_project\venv\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics = ['accuracy'])          
history = model.fit(x_train, y_train, epochs = 15, batch_size = 32, validation_data = (x_test, y_test))
# Out:
# WARNING:tensorflow:From e:\ML_project\venv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/15
# WARNING:tensorflow:From e:\ML_project\venv\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From e:\ML_project\venv\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 158/158 [==============================] - 2s 3ms/step - loss: 0.2137 - accuracy: 0.9188 - val_loss: 0.4564 - val_accuracy: 1.0000
# Epoch 2/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 0.9998 - val_loss: 0.0871 - val_accuracy: 1.0000
# Epoch 3/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 0.9982 - val_loss: 0.0137 - val_accuracy: 1.0000
# Epoch 4/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0158 - accuracy: 0.9964 - val_loss: 7.5035e-04 - val_accuracy: 1.0000
# Epoch 5/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 0.9929 - val_loss: 5.1456e-04 - val_accuracy: 1.0000
# Epoch 6/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0234 - accuracy: 0.9940 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 7/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 0.9907 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 8/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0280 - accuracy: 0.9911 - val_loss: 3.4401e-04 - val_accuracy: 1.0000
# Epoch 9/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0307 - accuracy: 0.9903 - val_loss: 4.1806e-04 - val_accuracy: 1.0000
# Epoch 10/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0222 - accuracy: 0.9933 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 11/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 0.9956 - val_loss: 1.0361e-04 - val_accuracy: 1.0000
# Epoch 12/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 0.9934 - val_loss: 0.8411 - val_accuracy: 0.6587
# Epoch 13/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0613 - accuracy: 0.9831 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 14/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9933 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 15/15
# 158/158 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 0.9887 - val_loss: 3.8940e-04 - val_accuracy: 1.0000

# %%
model.save('E:\\ML_project\\models\\model_kbb1.h5')
print("Da luu")
# Out:
# Da luu
# e:\ML_project\venv\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
